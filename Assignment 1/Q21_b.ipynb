# %%
import pandas as pd
import statsmodels.api as sm

# %%
df=pd.read_csv(r"D:\DS PYTHON\Assignment\wc-at.csv")

# %%
df
# Out:
#       Waist      AT
# 0     74.75   25.72
# 1     72.60   25.89
# 2     81.80   42.60
# 3     83.95   42.80
# 4     74.65   29.84
# ..      ...     ...
# 104  100.10  124.00
# 105   93.30   62.20
# 106  101.80  133.00
# 107  107.90  208.00
# 108  108.50  208.00
#
# [109 rows x 2 columns]

# %%
df.hist('Waist')
# Out:
# array([[<AxesSubplot:title={'center':'Waist'}>]], dtype=object)

# %%
df['Waist'].skew()
# Out:
# 0.1340560824786468

# %%
sm.qqplot(df['Waist'],line='r');

# %%
# Checking normal distribution for AT column

# %%
df.hist('AT')
# Out:
# array([[<AxesSubplot:title={'center':'AT'}>]], dtype=object)

# %%
df['AT'].skew()
# Out:
# 0.584869324127853

# %%
sm.qqplot(df['AT'],line='r');

# %% [markdown]
# ###### Waist column in the data set is following normal distribution as there is neglegible skewness

# %% [markdown]
# ##### AT column in the data set is skewed towards right so it is not following the normal distribution
